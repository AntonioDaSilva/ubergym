# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
with open("../data/qlearning_driver0_rewards.pkl", "rb") as f:
    rewards = pickle.load(f)

plt.title("Q Learning Driver Rewards Per Step")
plt.xlabel("Step")
plt.ylabel("Rewards")
plt.plot(np.arange(len(rewards)), rewards)
